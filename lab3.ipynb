# %% [markdown]
# <a href="https://colab.research.google.com/github/SW0301/MMVSU/blob/main/lab3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Лаб 3

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.integrate import odeint

h = 2

def dydt(y,t):
    k=0.42
    return k * y

def ode(dydt,y0,t,n):
  t=[t]
  y=[y0]
  for i in range(n-1):
    ti=t[i]
    yi=y[i]
    yi1=yi+h*dydt(yi,ti)
    y.append(yi1)
    t.append(ti+h)
  return t, y


t = np.arange(0, 10+h, h) 
t1 = np.linspace(0,10,1000)
t, y = ode(dydt, y0=1, t=0, n=len(t-1))


solve = odeint(dydt, y0=1, t=t1)
solve = solve.flatten()

plt.plot(t1,solve, label = r"odeint")

plt.plot(t, y, label = r"$x' = kx$")
plt.grid(True)
plt.legend()
plt.show()
