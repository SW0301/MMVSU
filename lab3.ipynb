# %% [markdown]
# <a href="https://colab.research.google.com/github/SW0301/MMVSU/blob/main/lab3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

url = 'https://raw.githubusercontent.com/SW0301/MMVSU/main/lab2.csv'
df = pd.read_csv(url)
print(df)
years = np.array(df['Year'])
population = np.array(df['Population'])
plt.plot(years, population)
plt.show
# Out:
#     Year  Population
# 0   1811       14400
# 1   1840       31900
# 2   1856       35800
# 3   1863       41500
# 4   1897       90000
# 5   1913      111400
# 6   1914      111600
# 7   1923      135400
# 8   1926      221544
# 9   1931      350251
# 10  1933      451500
# 11  1937      575704
# 12  1939      643689
# 13  1956      876000
# 14  1959      941962
# 15  1962     1025000
# 16  1967     1120000
# 17  1970     1170133
# 18  1973     1238000
# 19  1975     1305000
# 20  1979     1344474
# 21  1982     1373000
# 22  1985     1405000
# 23  1986     1401000
# 24  1987     1425000
# 25  1989     1438133
# 26  1990     1404000
# 27  1991     1445000
# 28  1992     1441000
# 29  1993     1433000
# 30  1994     1425000
# 31  1995     1379000
# 32  1996     1372000
# 33  1997     1371000
# 34  1998     1364000
# 35  1999     1364900
# 36  2000     1357000
# 37  2001     1343300
# 38  2002     1311252
# 39  2003     1309000
# 40  2004     1296800
# 41  2005     1289500
# ...
